# %% [markdown]
# ![판다](https://i.imgur.com/IH2fnKE.jpg)

# %%
-빨강
*노랑
+초록
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_31/3678272920.py in <module>
# ----> 1 -빨강
#       2 *노랑
#       3 +초록
#
# NameError: name '빨강' is not defined

# %%
- 빨강
  -노랑
    -초록
# Out:
#   File "/tmp/ipykernel_31/2904082740.py", line 2
#     -노랑
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# *qwer*
# _qweer_
# ~~cancle~~
# **mark**

# %% [markdown]
# ```
# print("hello")
# ```

# %%
print("hello, git!")
# Out:
# hello, git!
